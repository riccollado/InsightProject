# %%
import io
import os

from generator_network import generate_network

#%matplotlib notebook
# %matplotlib inline
import matplotlib.pyplot as plt

import networkx as nx

# %%
num_nodes = 35
num_layers = 6
density = 0.3
G, figure = generate_network(num_nodes, num_layers, density)

# %%
#Later we write the file to disk with:
temporarylocation="testout.pdf"

with open(temporarylocation,'wb') as out:
    out.write(figure.getvalue())
    out.close()
